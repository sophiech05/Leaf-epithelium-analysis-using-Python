# %%
#imports
import napari
import utils
from utils import * 
from importlib import reload
reload(utils)
#mode : 'junction' or 'count'
mode = 'count'
# Out:
# Please put below the directory of the folder containing your images of interest:

# %% [markdown]
# ## Open the napari window to perform the image analysis

# %%
viewer = napari.Viewer()

# %%
viewer.window.add_dock_widget(get_image)
viewer.window.add_dock_widget(processing)
if mode == 'count':
    viewer.window.add_dock_widget(centroid)    
if mode == 'junction':
    viewer.window.add_dock_widget(skeleton)
    viewer.window.add_dock_widget(junctions)
